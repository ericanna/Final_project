# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dataset.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10690 entries, 0 to 10689
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   author_average_rating  10690 non-null  float64
#  1   author_gender          10690 non-null  object
#  2   author_genres          10690 non-null  object
#  3   author_id              10690 non-null  int64
#  4   author_name            10690 non-null  object
#  5   author_page_url        10690 non-null  object
#  6   author_rating_count    10690 non-null  int64
#  7   author_review_count    10690 non-null  int64
#  8   birthplace             10690 non-null  object
#  9   book_average_rating    10690 non-null  float64
#  10  book_fullurl           10690 non-null  object
#  11  book_id                10690 non-null  object
#  12  book_title             10690 non-null  object
#  13  genre_1                10690 non-null  object
#  14  genre_2                10690 non-null  object
#  15  num_ratings            10690 non-null  int64
#  16  num_reviews            10690 non-null  int64
#  17  pages                  10690 non-null  int64
#  18  publish_date           10581 non-null  object
#  19  score                  10690 non-null  int64
# dtypes: float64(2), int64(7), object(11)
# memory usage: 1.6+ MB

# %%
df.drop(columns = ["author_gender", "author_average_rating", "author_genres", "author_rating_count", "author_review_count", "num_ratings", "num_reviews", "score"], inplace=True)

# %%
df = df[df['book_average_rating'] >= 3.5]  # removing books with average rating less than 3.5 to keep a certain quality in the recomendations
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7700 entries, 0 to 10128
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   author_id            7700 non-null   int64
#  1   author_name          7700 non-null   object
#  2   author_page_url      7700 non-null   object
#  3   birthplace           7700 non-null   object
#  4   book_average_rating  7700 non-null   float64
#  5   book_fullurl         7700 non-null   object
#  6   book_id              7700 non-null   object
#  7   book_title           7700 non-null   object
#  8   genre_1              7700 non-null   object
#  9   genre_2              7700 non-null   object
#  10  pages                7700 non-null   int64
#  11  publish_date         7608 non-null   object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 782.0+ KB

# %%
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7700 entries, 0 to 10128
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   author_id            7700 non-null   int64
#  1   author_name          7700 non-null   object
#  2   author_page_url      7700 non-null   object
#  3   birthplace           7700 non-null   object
#  4   book_average_rating  7700 non-null   float64
#  5   book_fullurl         7700 non-null   object
#  6   book_id              7700 non-null   object
#  7   book_title           7700 non-null   object
#  8   genre_1              7700 non-null   object
#  9   genre_2              7700 non-null   object
#  10  pages                7700 non-null   int64
#  11  publish_date         7608 non-null   object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 782.0+ KB

# %%
df.reset_index(drop=True)
df.head()
# Out:
#    author_id           author_name                           author_page_url  \
# 0      74489    Victoria Thompson       /author/show/74489.Victoria_Thompson
# 1    5618190  Mimi Jean Pamfiloff   /author/show/5618190.Mimi_Jean_Pamfiloff
# 2      36122    Patricia C. Wrede        /author/show/36122.Patricia_C_Wrede
# 3    4833990         Jillian Dodd          /author/show/4833990.Jillian_Dodd
# 4       7956           Mary Roach               /author/show/7956.Mary_Roach
#
#        birthplace  book_average_rating  \
# 0  USA and Canada                 4.02
# 1  USA and Canada                 3.99
# 2  USA and Canada                 4.01
# 3         Unknown                 3.95
# 4  USA and Canada                 3.84
#
#                                         book_fullurl   book_id  \
# 0  https://www.goodreads.com/book/show/686717.Mur...    686717
# 1  https://www.goodreads.com/book/show/27833684-t...  27833684
# 2  https://www.goodreads.com/book/show/64207.Sorc...     64207
# 3  https://www.goodreads.com/book/show/34804503-s...  34804503
# 4   https://www.goodreads.com/book/show/5981308-bonk   5981308
#
#                                           book_title      genre_1  \
# 0                        Murder on St. Mark's Place       Mystery
# 1                              Tailored for Trouble       Romance
# 2         Sorcery & Cecelia: or The Enchanted Cho...      Fantasy
# 3                                          Stalk Me   Young Adult
# 4         Bonk: The Curious Coupling of Science a...   Nonfiction
#
#         genre_2  pages      publish_date
# 0    Historical    277              2000
# 1  Contemporary    354              2016
# 2   Young Adult    326   April 15th 1988
# 3       Romance    327  August 20th 2012
# 4       Science    319              2008

# %%
df['year_publication'] = df['publish_date'].str[-4:] # Getting only the year of publication
df['year_publication'].unique()
# Out:
# array(['2000', '2016', '1988', '2012', '2008', '1993', '2007', '2006',
#        '2010', '2014', '2013', '1987', '2011', '1974', '2002', '1957',
#        '1992', '2003', '2009', '1997', '1938', '1813', '1868', '1943',
#        '1963', '1989', '2001', '2005', '2004', nan, '1936', '2015',
#        '1995', '1980', '1978', '1994', '1998', 'by', '1981', '1982',
#        '1970', '1905', '1976', '1983', '1977', '1986', '1962', '2018',
#        '1999', '2017', '1967', '1918', '1937', '1818', '1847', '1947',
#        '1960', '1961', '1990', '1996', '1949', '1935', '1985', '1944',
#        '1954', '1945', '1908', '1973', '1972', '1971', '1877', '1959',
#        '1948', '1991', '1922', '29th', '2nd', '7th', '5th', '4th', '30th',
#        '10th', '2019', '1984', '1927', '1931', '1934', '1975', '1923',
#        '1930', '1955', '1942', '1902', '1920', '1855', '1952', '1964',
#        '1880', '1892', '3rd', '26th', '1871', '1968', '1932', '1979',
#        '1830', '1899', '1848', '1925', '1792', '1969', '1953', '1940',
#        '1950', '1956', '1911', '1965', '1929', '1966', '1915', '1894',
#        '1008', '1939', '1958', '1862', '1797', '1307', '1861', '1900',
#        '1951', '1811', '-600', '1917', '1850', '1890', '12th', '25th',
#        '19th', '1st', '1926', '9th', '1928', '1893', '1817', '1853',
#        '1924', '1913', '1901', '1921', '1933', '1903', '1906', '11th',
#        '1879', '1946', '1393', '1898', '1778', '1912', '1916', '23rd',
#        '27th', '18th', '6th', '28th', '1801', '21st', '14th', '1897',
#        '1865', '1941', 'd 17'], dtype=object)

# %%
# I checked in Goodreads that the publication dates with only days belong to books released in 2019. Probably an error in the API that affected the data gathering.

def cleaning_date(i):
    if i in ['29th', '2nd', '7th', '5th', '4th', '30th','10th', '26th', '9th', '11th', '23rd',
       '27th', '18th', '6th', '28th', '21st', '14th', '12th', '25th', '1st', '3rd']:
        return '2019'
    elif i == 'by': # these books don't have publication dates on the dataset, so these are null
        return 0
    else:
        return i

# %%
df['year_publication'] = list(map(cleaning_date, df['year_publication']))
df['year_publication'].unique()
# Out:
# array(['2000', '2016', '1988', '2012', '2008', '1993', '2007', '2006',
#        '2010', '2014', '2013', '1987', '2011', '1974', '2002', '1957',
#        '1992', '2003', '2009', '1997', '1938', '1813', '1868', '1943',
#        '1963', '1989', '2001', '2005', '2004', nan, '1936', '2015',
#        '1995', '1980', '1978', '1994', '1998', 0, '1981', '1982', '1970',
#        '1905', '1976', '1983', '1977', '1986', '1962', '2018', '1999',
#        '2017', '1967', '1918', '1937', '1818', '1847', '1947', '1960',
#        '1961', '1990', '1996', '1949', '1935', '1985', '1944', '1954',
#        '1945', '1908', '1973', '1972', '1971', '1877', '1959', '1948',
#        '1991', '1922', '2019', '1984', '1927', '1931', '1934', '1975',
#        '1923', '1930', '1955', '1942', '1902', '1920', '1855', '1952',
#        '1964', '1880', '1892', '1871', '1968', '1932', '1979', '1830',
#        '1899', '1848', '1925', '1792', '1969', '1953', '1940', '1950',
#        '1956', '1911', '1965', '1929', '1966', '1915', '1894', '1008',
#        '1939', '1958', '1862', '1797', '1307', '1861', '1900', '1951',
#        '1811', '-600', '1917', '1850', '1890', '19th', '1926', '1928',
#        '1893', '1817', '1853', '1924', '1913', '1901', '1921', '1933',
#        '1903', '1906', '1879', '1946', '1393', '1898', '1778', '1912',
#        '1916', '1801', '1897', '1865', '1941'], dtype=object)

# %%
df.loc[df['year_publication'] == 'd 17', 'year_publication'] = '2014' # checked the right date on Goodreads

# %%
df['year_publication'].unique()
# Out:
# array(['2000', '2016', '1988', '2012', '2008', '1993', '2007', '2006',
#        '2010', '2014', '2013', '1987', '2011', '1974', '2002', '1957',
#        '1992', '2003', '2009', '1997', '1938', '1813', '1868', '1943',
#        '1963', '1989', '2001', '2005', '2004', nan, '1936', '2015',
#        '1995', '1980', '1978', '1994', '1998', 0, '1981', '1982', '1970',
#        '1905', '1976', '1983', '1977', '1986', '1962', '2018', '1999',
#        '2017', '1967', '1918', '1937', '1818', '1847', '1947', '1960',
#        '1961', '1990', '1996', '1949', '1935', '1985', '1944', '1954',
#        '1945', '1908', '1973', '1972', '1971', '1877', '1959', '1948',
#        '1991', '1922', '2019', '1984', '1927', '1931', '1934', '1975',
#        '1923', '1930', '1955', '1942', '1902', '1920', '1855', '1952',
#        '1964', '1880', '1892', '1871', '1968', '1932', '1979', '1830',
#        '1899', '1848', '1925', '1792', '1969', '1953', '1940', '1950',
#        '1956', '1911', '1965', '1929', '1966', '1915', '1894', '1008',
#        '1939', '1958', '1862', '1797', '1307', '1861', '1900', '1951',
#        '1811', '-600', '1917', '1850', '1890', '19th', '1926', '1928',
#        '1893', '1817', '1853', '1924', '1913', '1901', '1921', '1933',
#        '1903', '1906', '1879', '1946', '1393', '1898', '1778', '1912',
#        '1916', '1801', '1897', '1865', '1941'], dtype=object)

# %%
df.to_csv("dataset_clean3.csv", index = False)

# %%
df['genre_1'].unique()
# Out:
# array(['Mystery', 'Romance', 'Fantasy', 'Young Adult', 'Nonfiction',
#        'Paranormal', 'Historical', 'Science Fiction', 'Fiction',
#        'Classics', 'New Adult', 'Contemporary', 'Womens Fiction',
#        'Horror', 'Autobiography', 'Humor', 'Sequential Art', 'Lgbt',
#        'Sports and Games', 'War', 'Dark', 'Childrens',
#        'Christian Fiction', 'Warfare', 'Biography', 'Adult Fiction',
#        'Short Stories', 'Animals', 'Shapeshifters', 'Self Help', 'Music',
#        'Politics', 'Mental Health', 'Erotica', 'Crime', 'Travel',
#        'History', 'Language', 'Poetry', 'Novels', 'Feminism', 'Thriller',
#        'Mythology', 'World War II', 'Anthologies', 'Death',
#        'Magical Realism', 'Christian', 'Realistic Fiction', 'Suspense',
#        'Category Romance', 'Cultural', 'Science Fiction Fantasy', 'Amish',
#        'Holiday', 'Psychology', 'Philosophy', 'Glbt', 'Sexuality',
#        'Parenting', 'Gardening', 'Spirituality', 'Literary Fiction',
#        'Novella', 'Asian Literature', 'Sociology', 'Business',
#        'Food and Drink', 'Media Tie In', 'Health', 'Religion',
#        'Biblical Fiction', 'Couture', 'Adventure', 'Literature',
#        'Writing', 'Polyamorous', 'Retellings', 'Westerns', 'Dark Fantasy',
#        'Comics', 'Inspirational', 'Drama', 'Unfinished', 'Sports', 'Art',
#        'Economics', 'Social Science', 'Manga'], dtype=object)

# %%
df['fiction_nonfiction'] = df['genre_1']
df
# Out:
#        author_id           author_name  \
# 0          74489    Victoria Thompson
# 1        5618190  Mimi Jean Pamfiloff
# 2          36122    Patricia C. Wrede
# 3        4833990         Jillian Dodd
# 4           7956           Mary Roach
# ...          ...                   ...
# 10124   12020546          S.D. Wasley
# 10125    8386732         Victoria Zak
# 10126     108007       Dakota Cassidy
# 10127    6543639      Krystal Shannan
# 10128    5246010          Bryce Evans
#
#                                 author_page_url      birthplace  \
# 0          /author/show/74489.Victoria_Thompson  USA and Canada
# 1      /author/show/5618190.Mimi_Jean_Pamfiloff  USA and Canada
# 2           /author/show/36122.Patricia_C_Wrede  USA and Canada
# 3             /author/show/4833990.Jillian_Dodd         Unknown
# 4                  /author/show/7956.Mary_Roach  USA and Canada
# ...                                         ...             ...
# 10124          /author/show/12020546.S_D_Wasley         Oceania
# 10125         /author/show/8386732.Victoria_Zak         Unknown
# 10126        /author/show/108007.Dakota_Cassidy         Unknown
# 10127      /author/show/6543639.Krystal_Shannan  USA and Canada
# 10128          /author/show/5246010.Bryce_Evans         Unknown
#
#        book_average_rating                                       book_fullurl  \
# 0                     4.02  https://www.goodreads.com/book/show/686717.Mur...
# 1                     3.99  https://www.goodreads.com/book/show/27833684-t...
# 2                     4.01  https://www.goodreads.com/book/show/64207.Sorc...
# 3                     3.95  https://www.goodreads.com/book/show/34804503-s...
# 4                     3.84   https://www.goodreads.com/book/show/5981308-bonk
# ...                    ...                                                ...
# 10124                 4.05  https://www.goodreads.com/book/show/24474924-t...
# 10125                 4.22  https://www.goodreads.com/book/show/23552511-h...
# 10126                 3.82  https://www.goodreads.com/book/show/24614174-g...
# 10127                 3.73  https://www.goodreads.com/book/show/35892811-m...
# 10128                 3.89  https://www.goodreads.com/book/show/17187320-t...
#
#         book_id                                         book_title  \
# 0        686717                        Murder on St. Mark's Place
# 1      27833684                              Tailored for Trouble
# 2         64207         Sorcery & Cecelia: or The Enchanted Cho...
# 3      34804503                                          Stalk Me
# 4       5981308         Bonk: The Curious Coupling of Science a...
# ...         ...                                                ...
# 10124  24474924                                       The Seventh
# 10125  23552511                                    Highland Storm
# 10126  24614174                                  Gotta Have Faith
# 10127  35892811                                 My Viking Vampire
# 10128  17187320                                       The Trinity
#
#            genre_1       genre_2  pages        publish_date year_publication  \
# 0          Mystery    Historical    277                2000             2000
# 1          Romance  Contemporary    354                2016             2016
# 2          Fantasy   Young Adult    326     April 15th 1988             1988
# 3      Young Adult       Romance    327    August 20th 2012             2012
# 4       Nonfiction       Science    319                2008             2008
# ...            ...           ...    ...                 ...              ...
# 10124  Young Adult       Fantasy    262                2015             2015
# 10125      Romance       Romance    232                2015             2015
# 10126      Fantasy       Romance     72                2015             2015
# 10127      Fantasy    Paranormal    237    January 1st 2014             2014
# 10128      Fantasy    Paranormal    222  December 28th 2012             2012
#
#       fiction_nonfiction
# 0                Mystery
# 1                Romance
# 2                Fantasy
# 3            Young Adult
# 4             Nonfiction
# ...                  ...
# 10124        Young Adult
# 10125            Romance
# 10126            Fantasy
# 10127            Fantasy
# 10128            Fantasy
#
# [7700 rows x 14 columns]

# %%
df.reset_index(drop=True)
# Out:
#       author_id           author_name  \
# 0         74489    Victoria Thompson
# 1       5618190  Mimi Jean Pamfiloff
# 2         36122    Patricia C. Wrede
# 3       4833990         Jillian Dodd
# 4          7956           Mary Roach
# ...         ...                   ...
# 7695   12020546          S.D. Wasley
# 7696    8386732         Victoria Zak
# 7697     108007       Dakota Cassidy
# 7698    6543639      Krystal Shannan
# 7699    5246010          Bryce Evans
#
#                                author_page_url      birthplace  \
# 0         /author/show/74489.Victoria_Thompson  USA and Canada
# 1     /author/show/5618190.Mimi_Jean_Pamfiloff  USA and Canada
# 2          /author/show/36122.Patricia_C_Wrede  USA and Canada
# 3            /author/show/4833990.Jillian_Dodd         Unknown
# 4                 /author/show/7956.Mary_Roach  USA and Canada
# ...                                        ...             ...
# 7695          /author/show/12020546.S_D_Wasley         Oceania
# 7696         /author/show/8386732.Victoria_Zak         Unknown
# 7697        /author/show/108007.Dakota_Cassidy         Unknown
# 7698      /author/show/6543639.Krystal_Shannan  USA and Canada
# 7699          /author/show/5246010.Bryce_Evans         Unknown
#
#       book_average_rating                                       book_fullurl  \
# 0                    4.02  https://www.goodreads.com/book/show/686717.Mur...
# 1                    3.99  https://www.goodreads.com/book/show/27833684-t...
# 2                    4.01  https://www.goodreads.com/book/show/64207.Sorc...
# 3                    3.95  https://www.goodreads.com/book/show/34804503-s...
# 4                    3.84   https://www.goodreads.com/book/show/5981308-bonk
# ...                   ...                                                ...
# 7695                 4.05  https://www.goodreads.com/book/show/24474924-t...
# 7696                 4.22  https://www.goodreads.com/book/show/23552511-h...
# 7697                 3.82  https://www.goodreads.com/book/show/24614174-g...
# 7698                 3.73  https://www.goodreads.com/book/show/35892811-m...
# 7699                 3.89  https://www.goodreads.com/book/show/17187320-t...
#
#        book_id                                         book_title  \
# 0       686717                        Murder on St. Mark's Place
# 1     27833684                              Tailored for Trouble
# 2        64207         Sorcery & Cecelia: or The Enchanted Cho...
# 3     34804503                                          Stalk Me
# 4      5981308         Bonk: The Curious Coupling of Science a...
# ...        ...                                                ...
# 7695  24474924                                       The Seventh
# 7696  23552511                                    Highland Storm
# 7697  24614174                                  Gotta Have Faith
# 7698  35892811                                 My Viking Vampire
# 7699  17187320                                       The Trinity
#
#           genre_1       genre_2  pages        publish_date year_publication  \
# 0         Mystery    Historical    277                2000             2000
# 1         Romance  Contemporary    354                2016             2016
# 2         Fantasy   Young Adult    326     April 15th 1988             1988
# 3     Young Adult       Romance    327    August 20th 2012             2012
# 4      Nonfiction       Science    319                2008             2008
# ...           ...           ...    ...                 ...              ...
# 7695  Young Adult       Fantasy    262                2015             2015
# 7696      Romance       Romance    232                2015             2015
# 7697      Fantasy       Romance     72                2015             2015
# 7698      Fantasy    Paranormal    237    January 1st 2014             2014
# 7699      Fantasy    Paranormal    222  December 28th 2012             2012
#
#      fiction_nonfiction
# 0               Mystery
# 1               Romance
# 2               Fantasy
# 3           Young Adult
# 4            Nonfiction
# ...                 ...
# 7695        Young Adult
# 7696            Romance
# 7697            Fantasy
# 7698            Fantasy
# 7699            Fantasy
#
# [7700 rows x 14 columns]

# %%
df.to_csv('dataset3.csv', index = False)

# %%
df.loc[df['year_publication'] == 'Nonfiction']
# Out:
# Empty DataFrame
# Columns: [author_id, author_name, author_page_url, birthplace, book_average_rating, book_fullurl, book_id, book_title, genre_1, genre_2, pages, publish_date, year_publication, fiction_nonfiction]
# Index: []
