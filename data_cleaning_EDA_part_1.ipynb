# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv("books_1.Best_Books_Ever.csv")
file1.head()
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                     1885.Pride_and_Prejudice
# 4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# ...

# %%
file1.drop(columns= [ "bookFormat", "publishDate"], inplace=True)
file1.head()
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                     1885.Pride_and_Prejudice
# 4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# ...

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52478 entries, 0 to 52477
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bookId            52478 non-null  object
#  1   title             52478 non-null  object
#  2   series            23470 non-null  object
#  3   author            52478 non-null  object
#  4   rating            52478 non-null  float64
#  5   description       51140 non-null  object
#  6   language          48672 non-null  object
#  7   isbn              52478 non-null  object
#  8   genres            52478 non-null  object
#  9   characters        52478 non-null  object
#  10  edition           4955 non-null   object
#  11  pages             50131 non-null  object
#  12  publisher         48782 non-null  object
#  13  firstPublishDate  31152 non-null  object
#  14  awards            52478 non-null  object
#  15  numRatings        52478 non-null  int64
# ...

# %%
file2 = pd.read_csv('final_dataset.csv')
file2.head()
# Out:
#    authorid                   name  workcount  fan_count   gender  \
# 0   8409092        Jason   Wallace          2         13     male
# 1   5796406           Rosan Hollak          4          0  unknown
# 2   8421525             Nanna Foss          6        156   female
# 3    158146      Terri Savelle Foy         23        125   female
# 4  15340731  Vishwas Nangare Patil          1        127  unknown
#
#                                            image_url  \
# 0  https://images.gr-assets.com/authors/148926684...
# 1  https://s.gr-assets.com/assets/nophoto/user/u_...
# 2  https://images.gr-assets.com/authors/140908587...
# 3  https://images.gr-assets.com/authors/147569460...
# 4  https://s.gr-assets.com/assets/nophoto/user/u_...
#
#                                                about born died influence  \
# 0  Jason Wallace is related to Tolkien and a desc...  NaN  NaN       NaN
# 1                                                NaN  NaN  NaN       NaN
# ...

# %%
file2.drop(columns = ["workcount", "fan_count", "about", "born", "died", "influence", "website", "genre", "original_hometown", "latitude", "longitude"], inplace=True)
file2.head()
# Out:
#    authorid                   name   gender  \
# 0   8409092        Jason   Wallace     male
# 1   5796406           Rosan Hollak  unknown
# 2   8421525             Nanna Foss   female
# 3    158146      Terri Savelle Foy   female
# 4  15340731  Vishwas Nangare Patil  unknown
#
#                                            image_url  average_rate  \
# 0  https://images.gr-assets.com/authors/148926684...          3.74
# 1  https://s.gr-assets.com/assets/nophoto/user/u_...          3.73
# 2  https://images.gr-assets.com/authors/140908587...          4.35
# 3  https://images.gr-assets.com/authors/147569460...          4.56
# 4  https://s.gr-assets.com/assets/nophoto/user/u_...          4.15
#
#    rating_count  review_count          twitter         country
# 0          1028           175              NaN  United Kingdom
# 1            15             1              NaN             NaN
# 2          1172           205              NaN             NaN
# ...

# %%
file2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209517 entries, 0 to 209516
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   authorid      209517 non-null  int64
#  1   name          209517 non-null  object
#  2   gender        209517 non-null  object
#  3   image_url     209517 non-null  object
#  4   average_rate  209517 non-null  float64
#  5   rating_count  209517 non-null  int64
#  6   review_count  209517 non-null  int64
#  7   twitter       35122 non-null   object
#  8   country       44599 non-null   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 14.4+ MB

# %%
file2.groupby(file2["gender"]).count()
# Out:
#          authorid    name  image_url  average_rate  rating_count  \
# gender
# female      41761   41761      41761         41761         41761
# male        46783   46783      46783         46783         46783
# unknown    120973  120973     120973        120973        120973
#
#          review_count  twitter  country
# gender
# female          41761    17986    15582
# male            46783    10506    23336
# unknown        120973     6630     5681

# %%
file3 = pd.read_csv('good_reads_final.csv')
file3.head()
# Out:
#    author_average_rating author_gender                          author_genres  \
# 0                   4.01        female                    historical-fiction,
# 1                   4.15          male  literature-fiction,mystery-thrillers,
# 2                   4.00        female                               romance,
# 3                   3.88          male                        fiction,memoir,
# 4                   4.10        female                   young-adult,fantasy,
#
#    author_id            author_name                           author_page_url  \
# 0      74489    Victoria Thompson\n      /author/show/74489.Victoria_Thompson
# 1     706255        Stieg Larsson\n         /author/show/706255.Stieg_Larsson
# 2    5618190  Mimi Jean Pamfiloff\n  /author/show/5618190.Mimi_Jean_Pamfiloff
# 3      37871          José Donoso\n             /author/show/37871.Jos_Donoso
# 4      36122    Patricia C. Wrede\n       /author/show/36122.Patricia_C_Wrede
#
# ...

# %%
file3.groupby(file3["author_gender"]).count()
# Out:
#                author_average_rating  author_genres  author_id  author_name  \
# author_gender
# female                         10690          10690      10690        10690
# male                           12201          12201      12201        12201
#
#                author_page_url  author_rating_count  author_review_count  \
# author_gender
# female                   10690                10690                10690
# male                     12201                12201                12201
#
#                birthplace  book_average_rating  book_fullurl  book_id  \
# author_gender
# female              10690                10690         10690    10690
# male                12201                12201         12201    12201
#
#                book_title  genre_1  genre_2  num_ratings  num_reviews  pages  \
# author_gender
# female              10690    10690    10690        10690        10690  10690
# male                12201    12201    12201        12201        12201  12201
#
# ...

# %%
women_df2 = file3[file3['author_gender'] == "female"].reset_index(drop=True)

# %%
women_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10690 entries, 0 to 10689
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   author_average_rating  10690 non-null  float64
#  1   author_gender          10690 non-null  object
#  2   author_genres          10690 non-null  object
#  3   author_id              10690 non-null  int64
#  4   author_name            10690 non-null  object
#  5   author_page_url        10690 non-null  object
#  6   author_rating_count    10690 non-null  int64
#  7   author_review_count    10690 non-null  int64
#  8   birthplace             10690 non-null  object
#  9   book_average_rating    10690 non-null  float64
#  10  book_fullurl           10690 non-null  object
#  11  book_id                10690 non-null  object
#  12  book_title             10690 non-null  object
#  13  genre_1                10690 non-null  object
# ...

# %%
women_df2.head()
# Out:
#    author_average_rating author_gender         author_genres  author_id  \
# 0                   4.01        female   historical-fiction,      74489
# 1                   4.00        female              romance,    5618190
# 2                   4.10        female  young-adult,fantasy,      36122
# 3                   4.16        female              romance,    4833990
# 4                   3.94        female           nonfiction,       7956
#
#              author_name                           author_page_url  \
# 0    Victoria Thompson\n      /author/show/74489.Victoria_Thompson
# 1  Mimi Jean Pamfiloff\n  /author/show/5618190.Mimi_Jean_Pamfiloff
# 2    Patricia C. Wrede\n       /author/show/36122.Patricia_C_Wrede
# 3         Jillian Dodd\n         /author/show/4833990.Jillian_Dodd
# 4           Mary Roach\n              /author/show/7956.Mary_Roach
#
#    author_rating_count  author_review_count            birthplace  \
# ...

# %%
women_df2['author_name'] = women_df2['author_name'].replace(r'\n',' ', regex=True) 
women_df2['book_title'] = women_df2['book_title'].replace(r'\n',' ', regex=True) 
women_df2['birthplace'] = women_df2['birthplace'].replace(r'\n',' ', regex=True) 
women_df2
# Out:
#        author_average_rating author_gender         author_genres  author_id  \
# 0                       4.01        female   historical-fiction,      74489
# 1                       4.00        female              romance,    5618190
# 2                       4.10        female  young-adult,fantasy,      36122
# 3                       4.16        female              romance,    4833990
# 4                       3.94        female           nonfiction,       7956
# ...                      ...           ...                   ...        ...
# 10685                   4.08        female           paranormal,   12020546
# 10686                   4.09        female              romance,    8386732
# 10687                   3.94        female     humor-and-comedy,     108007
# 10688                   4.00        female              romance,    6543639
# 10689                   4.20        female           paranormal,    5246010
#
# ...

# %%
women_df2.groupby(women_df2["birthplace"]).count()
# Out:
#                                       author_average_rating  author_gender  \
# birthplace
#                                                        2274           2274
#                                                         239            239
#     United Kingdom                                      185            185
#     United Kingdom                                       46             46
#     United States                                      2094           2094
# ...                                                     ...            ...
# Viet Nam                                                  2              2
# Virginia                                                  1              1
# Zimbabwe                                                  3              3
# Zimbabwe                                                  1              1
# the Former Yugoslav Republic of                           1              1
#
# ...

# %%
women_df2["birthplace"].unique()
# Out:
# array([' United States     ', ' United States   ', '   ', '   Canada   ',
#        '    United States   ', ' United Kingdom   ', '   Belgium   ',
#        'Cuba   ', 'Canada   ', 'Australia   ', '    United Kingdom   ',
#        '    United States     ', 'Colorado     ',
#        'Russian Federation     ', ' United Kingdom     ', 'Germany     ',
#        'England     ', 'France   ', '   Kenya   ', '   Chicago   ',
#        'Alabama   ', 'Russian Federation   ', 'Iran   ', 'Israel     ',
#        'New York   ', 'Ireland   ', 'KY   ', '        ', '   Mexico     ',
#        'Canada     ', '   Australia   ', '   Ireland   ', 'TX   ',
#        'Iran     ', 'Japan     ', 'South Africa   ', 'China     ',
#        '   China   ', 'Peru   ', 'India   ', 'Serbia   ', 'Mexico     ',
#        'Ireland     ', '   Canada     ', 'India     ', 'Australia     ',
#        'Hungary     ', 'Sweden     ', '   Mexico   ', 'Zimbabwe   ',
#        'NH   ', 'Missouri   ', 'Netherlands     ', 'Sri Lanka   ',
# ...

# %%
women_df2.loc[women_df2['birthplace'].str.contains("D.C."),'birthplace'] = "USA"
women_df2['birthplace'].unique()
# Out:
# array([' United States     ', ' United States   ', '   ', '   Canada   ',
#        '    United States   ', ' United Kingdom   ', '   Belgium   ',
#        'Cuba   ', 'Canada   ', 'Australia   ', '    United Kingdom   ',
#        '    United States     ', 'Colorado     ',
#        'Russian Federation     ', ' United Kingdom     ', 'Germany     ',
#        'England     ', 'France   ', '   Kenya   ', '   Chicago   ',
#        'Alabama   ', 'Russian Federation   ', 'Iran   ', 'Israel     ',
#        'New York   ', 'Ireland   ', 'KY   ', '        ', '   Mexico     ',
#        'Canada     ', '   Australia   ', '   Ireland   ', 'TX   ',
#        'Iran     ', 'Japan     ', 'South Africa   ', 'China     ',
#        '   China   ', 'Peru   ', 'India   ', 'Serbia   ', 'Mexico     ',
#        'Ireland     ', '   Canada     ', 'India     ', 'Australia     ',
#        'Hungary     ', 'Sweden     ', '   Mexico   ', 'Zimbabwe   ',
#        'NH   ', 'Missouri   ', 'Netherlands     ', 'Sri Lanka   ',
# ...

# %%
# Separating the authors by regions    

def north_america(i):
    if i== "North America" or i== "USA" or i=="Canada" or i=='Delaware   ' or i== '   Vancouver   ' or i=='Virginia   ' or i=='   Puerto Rico   ' or i=='   Wichita Falls     ' or i=='Indiana   ' or i== '   Winnipeg   ' or i=='   Indianapolis   ' or i=='Rhode Island     ' or i=='Puerto Rico   ' or i== ' United States     ' or i== ' United States   ' or i=='   Canada   ' or i=='    United States   ' or i=='Canada  ' or i=='    United States     ' or i== 'Colorado     ' or i=='   Chicago   ' or i== 'Alabama   ' or i=='New York   ' or i== 'KY   ' or i=='Canada     ' or i== 'TX   ' or i=='Canada   ' or i=='NH   ' or i== 'Missouri   ' or i== 'Massachusetts     ' or i=='   Boston   ' or i== 'Hawaii     ' or i== 'Kentucky     ' or i== 'Minnesota   ' or i=='Maryland   ' or i== 'PA   ' or i== '   Minneapolis   ' or i=='   Salt Lake City   ' or i== '   Baltimore   ' or i== 'Georgia   ' or i=='   Canada     ' or i== 'Illinois   ' or i=='   Rocky Mount     ' or i== '   Minneapolis     ' or i== 'KS   ' or i=='   New York      ' or i== 'Ohio    ' or i== 'VA   ' or i== '   Dallas   ' or i== 'Missouri     ' or i== '   Cleveland   ' or i== 'North Carolina     ' or i=='   Los Angeles   ' or i=='Illinois     ' or i== 'IL    ' or i== '   NYC   ' or i== 'NY   ' or i=='   Somewhere snowy MN   ' or i== 'NY     ' or i== 'Ohio     ' or i=='MI     ' or i=='CA   ' or i== '   California   ' or i== 'MA   ' or i== 'Ohio   ' or i == 'CA     ' or i== 'MA     ' or i== '   Ft. Lauderdale   ' or i== 'IL   ' or i== 'DC   ' or i=='MN   ' or i== '   Westminister CA   ' or i== 'N.Y.   ' or i=='California     ' or i== 'American Samoa   ' or i=='Florida   ' or i=='KY      ' or i== '   New York   ' or i== '   Manhattan   ' or i=='   Seattle   ' or i=='Canada    ':
        return "USA and Canada"
    else:
        return i
    
women_df2['birthplace'] = list(map(north_america, women_df2['birthplace']))

# %%
def latin_america(i):
    if i=='Cuba   ' or i== 'Cuba     ' or i=='   Cuba   ' or i=='Peru   ' or i=='Dominican Republic   ' or i=='Chile     ' or i=='Brazil     ' or i=='   Brazil   ' or i=='   Chile   ' or i=='Panama   ' or i=='   Trinidad and Tobago   ' or i=='Haiti     ' or i=='Ecuador   ' or i=='Argentina     ' or i=='Argentina   ' or i=='Guyana   ' or i=='   Mexico   ' or i=='   Jamaica   ' or i=='Mexico   ' or i=='   Argentina   ' or i=='Dominica     ' or i=='Venezuela     ' or i=='   Mexico     ' or i== 'Mexico     ':
        return "Latin America"
    else:
        return i
    
women_df2['birthplace'] = list(map(latin_america, women_df2['birthplace']))

# %%
def europe(i):
    if i== ' United Kingdom   ' or i=='   Belgium   ' or i=='    United Kingdom   ' or i=='Russian Federation     ' or i==' United Kingdom     ' or i=='Germany     ' or i=='England     ' or i== 'France   ' or i=='Russian Federation   ' or i=='Ireland   ' or i=='   Ireland   ' or i=='Hungary     ' or i== 'Sweden     ' or i=='Netherlands     ' or i=='   Denmark     ' or i== '    United Kingdom     ' or i=='Czech Republic     ' or i== 'Sweden   ' or i=='Scotland     ' or i=='   Sweden   ' or i=='Switzerland     ' or i== '   Germany   ' or i=='France     ' or i== '   Ukraine   ' or i== 'Poland   ' or i=='Iceland     ' or i== 'England   ' or i== 'Portugal   ' or i=='Belgium   ' or i=='   Portugal   ' or i=='North Wales   ' or i=='North Wales   ' or i== '   Croatia     ' or i== 'France     ' or i== 'Serbia   ' or i=='   Ireland     ' or i=='Germany   ' or i=='Austria     ' or i=='Denmark     ' or i== 'Poland     ' or i=='Netherlands   ' or i=='Slovakia     ' or i=='   Gibraltar     ' or i=='   Buckinghamshire   ' or i=='   France   ' or i=='Italy   ' or i=='Ireland     ' or i=='   Germany     ' or i=='Belgium     ' or i== '   Austria   ' or i== 'Greece     ' or i== 'Ukraine     ' or i== 'Croatia   ' or i== '   Italy   ' or i=='Italy     ' or i== 'Norway     ' or i=='   Bermuda   ' or i== '   Switzerland   ' or i== 'Finland   ' or i== 'Greece   ' or i=='Denmark   ' or i== '   Netherlands   ' or i== 'Switzerland   ' or i== '   Romania   ' or i== 'Finland     ' or i== 'Lithuania     ' or i== '   Norway   ' or i=='   Russian Federation   ' or i=='   Russian Federation     ' or i=='Holy See (vatican City State)   ' or i== 'Turkey     ' or i=='   Turkey     ' or i== 'Turkey   ' or i=='   Slovenia     ' or i=='Romania   ' or i=='the Former Yugoslav Republic of     ':
        return "Europe"
    else:
        return i

women_df2['birthplace'] = list(map(europe, women_df2['birthplace']))

# %%
def oceania(i):
    if i== 'Australia   ' or i=='   Australia   ' or i=='Australia     ' or i=='New Zealand   ' or i== '   Australia     ' or i=='   New Zealand   ' or i=='New Zealand     ':
        return "Oceania"
    else:
        return i

women_df2['birthplace'] = list(map(oceania, women_df2['birthplace']))

# %%
def africa(i):
    if i== '   Kenya   ' or i=='South Africa   ' or i=='Zimbabwe   ' or i=='   Malawi     ' or i== 'Nigeria     ' or i=='   Zambia   ' or i=='Somalia     ' or i== 'Uganda   ' or i=='Egypt     ' or i=='Morocco     ' or i== '   Cape Town   ' or i== '   South Africa   ' or i=='Somalia   ' or i=='South Africa     ' or i=='   South Africa     ' or i=='   Cameroon   ' or i=='Egypt   ' or i== '   Nigeria   ' or i=='   Congo   ' or i=='   Zimbabwe     ' or i=='Kenya   ' or i=='Zimbabwe     ' or i=='Senegal     ' or i== '   Mozambique   ' or i== '   Rwanda   ' or i=='Morocco   ' or i=='Malawi   ' or i=='Kenya     ':
        return "Africa"
    else:
        return i

women_df2['birthplace'] = list(map(africa, women_df2['birthplace']))

# %%
def asia(i):
    if i== 'Iran   ' or i== 'Israel     ' or i== '        ' or i== 'Iran     ' or i=='Japan     'or i== 'China     ' or i== '   China   ' or i== 'India   ' or i=='India     ' or i== 'Sri Lanka   ' or i== 'Pakistan     ' or i== 'Japan   ' or i=='Philippines   ' or i== '   Malaysia     ' or i== 'Indonesia   ' or i== 'Tunisia   ' or i=='   Japan     ' or i== '   India   ' or i=='   Cambodia   ' or i=='Bangladesh     ' or i== '   Israel   ' or i== '   Japan   ' or i=='   Iran   ' or i== '   China     ' or i== '   Hong Kong   ' or i== 'Pakistan   ' or i=='   Malaysia   ' or i== 'Taiwan   ' or i=='   Yemen   ' or i=='Viet Nam     ' or i=='Indonesia     ' or i== '   Philippines   ' or i== 'Singapore   ' or i==' United Arab Emirates   ' or i== '   India     ' or i=='   Singapore     ' or i== 'China   ' or i== 'Malaysia     ' or i=='   Jerusalem   ' or i== '   Taiwan     ' or i== 'Hong Kong   ' or i== '   Taiwan   ' or i=='   Indonesia   ' or i=='   Israel     ' or i== 'Syrian Arab Republic   ' or i=='Israel   ' or i== '   Sri Lanka   ' or i== 'Sri Lanka     ' or i== 'Philippines     ' or i=='   Kuwait   ':
        return "Asia"
    else:
        return i

women_df2['birthplace'] = list(map(asia, women_df2['birthplace']))

# %%
women_df2.loc[women_df2['birthplace'].str.contains("http://nikkiloftin.com/"), 'birthplace'] = "Unknown"

# %%
women_df2.loc[women_df2['birthplace'].str.contains("Republic of"), 'birthplace'] = "Unknown"
women_df2.loc[women_df2['birthplace'].str.contains("Occupied "), 'birthplace'] = "Unknown"
women_df2.loc[women_df2['birthplace'].str.contains("   "), 'birthplace'] = "Unknown"

# %%
women_df2['birthplace'].unique()
# Out:
# array(['USA and Canada', 'Unknown', 'Europe', 'Latin America', 'Oceania',
#        'Africa', 'Asia'], dtype=object)

# %%
women_df2.head()
# Out:
#    author_average_rating author_gender         author_genres  author_id  \
# 0                   4.01        female   historical-fiction,      74489
# 1                   4.00        female              romance,    5618190
# 2                   4.10        female  young-adult,fantasy,      36122
# 3                   4.16        female              romance,    4833990
# 4                   3.94        female           nonfiction,       7956
#
#             author_name                           author_page_url  \
# 0    Victoria Thompson       /author/show/74489.Victoria_Thompson
# 1  Mimi Jean Pamfiloff   /author/show/5618190.Mimi_Jean_Pamfiloff
# 2    Patricia C. Wrede        /author/show/36122.Patricia_C_Wrede
# 3         Jillian Dodd          /author/show/4833990.Jillian_Dodd
# 4           Mary Roach               /author/show/7956.Mary_Roach
#
#    author_rating_count  author_review_count      birthplace  \
# 0                74399                 6268  USA and Canada
# ...

# %%
women_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10690 entries, 0 to 10689
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   author_average_rating  10690 non-null  float64
#  1   author_gender          10690 non-null  object
#  2   author_genres          10690 non-null  object
#  3   author_id              10690 non-null  int64
#  4   author_name            10690 non-null  object
#  5   author_page_url        10690 non-null  object
#  6   author_rating_count    10690 non-null  int64
#  7   author_review_count    10690 non-null  int64
#  8   birthplace             10690 non-null  object
#  9   book_average_rating    10690 non-null  float64
#  10  book_fullurl           10690 non-null  object
#  11  book_id                10690 non-null  object
#  12  book_title             10690 non-null  object
#  13  genre_1                10690 non-null  object
# ...

# %%
women_df2.groupby(women_df2['birthplace']).count()
# Out:
#                 author_average_rating  author_gender  author_genres  \
# birthplace
# Africa                             87             87             87
# Asia                              589            589            589
# Europe                           1193           1193           1193
# Latin America                      73             73             73
# Oceania                           274            274            274
# USA and Canada                   6193           6193           6193
# Unknown                          2281           2281           2281
#
#                 author_id  author_name  author_page_url  author_rating_count  \
# birthplace
# Africa                 87           87               87                   87
# Asia                  589          589              589                  589
# Europe               1193         1193             1193                 1193
# Latin America          73           73               73                   73
# ...

# %%
women_df2.to_csv("dataset.csv", index=False)
