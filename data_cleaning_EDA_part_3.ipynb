# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset3.csv')
df
# Out:
#       author_id           author_name  \
# 0         74489    Victoria Thompson
# 1       5618190  Mimi Jean Pamfiloff
# 2         36122    Patricia C. Wrede
# 3       4833990         Jillian Dodd
# 4          7956           Mary Roach
# ...         ...                   ...
# 7695   12020546          S.D. Wasley
# 7696    8386732         Victoria Zak
# 7697     108007       Dakota Cassidy
# 7698    6543639      Krystal Shannan
# 7699    5246010          Bryce Evans
#
#                                author_page_url      birthplace  \
# 0         /author/show/74489.Victoria_Thompson  USA and Canada
# 1     /author/show/5618190.Mimi_Jean_Pamfiloff  USA and Canada
# 2          /author/show/36122.Patricia_C_Wrede  USA and Canada
# 3            /author/show/4833990.Jillian_Dodd         Unknown
# 4                 /author/show/7956.Mary_Roach  USA and Canada
# ...                                        ...             ...
# 7695          /author/show/12020546.S_D_Wasley         Oceania
# ...

# %%
df.iloc[6799,8] = 'Nonfiction'

# %%
df.iloc[2316,8] = 'Romance'

# %%
df.iloc[6927,13] ='Nonfiction'

# %%
df.iloc[3715,13] ='Nonfiction'

# %%
#df.drop(3715, inplace=True)
df.drop(columns = ['publish_date'], inplace=True)

# %%
df.drop(6310, inplace=True)

# %%
df.drop(6747, inplace=True)

# %%
df.reset_index(drop=True)
# Out:
#       author_id           author_name  \
# 0         74489    Victoria Thompson
# 1       5618190  Mimi Jean Pamfiloff
# 2         36122    Patricia C. Wrede
# 3       4833990         Jillian Dodd
# 4          7956           Mary Roach
# ...         ...                   ...
# 7693   12020546          S.D. Wasley
# 7694    8386732         Victoria Zak
# 7695     108007       Dakota Cassidy
# 7696    6543639      Krystal Shannan
# 7697    5246010          Bryce Evans
#
#                                author_page_url      birthplace  \
# 0         /author/show/74489.Victoria_Thompson  USA and Canada
# 1     /author/show/5618190.Mimi_Jean_Pamfiloff  USA and Canada
# 2          /author/show/36122.Patricia_C_Wrede  USA and Canada
# 3            /author/show/4833990.Jillian_Dodd         Unknown
# 4                 /author/show/7956.Mary_Roach  USA and Canada
# ...                                        ...             ...
# 7693          /author/show/12020546.S_D_Wasley         Oceania
# ...

# %%
df.to_csv('dataset4', index=False)

# %%
df = pd.read_csv('dataset4')
df
# Out:
#      author_id           author_name  \
# 0        74489    Victoria Thompson
# 1      5618190  Mimi Jean Pamfiloff
# 2        36122    Patricia C. Wrede
# 3      4833990         Jillian Dodd
# 4         7956           Mary Roach
# ...        ...                   ...
# 7692  12020546          S.D. Wasley
# 7693   8386732         Victoria Zak
# 7694    108007       Dakota Cassidy
# 7695   6543639      Krystal Shannan
# 7696   5246010          Bryce Evans
#
#                                author_page_url      birthplace  \
# 0         /author/show/74489.Victoria_Thompson  USA and Canada
# 1     /author/show/5618190.Mimi_Jean_Pamfiloff  USA and Canada
# 2          /author/show/36122.Patricia_C_Wrede  USA and Canada
# 3            /author/show/4833990.Jillian_Dodd         Unknown
# 4                 /author/show/7956.Mary_Roach  USA and Canada
# ...                                        ...             ...
# 7692          /author/show/12020546.S_D_Wasley         Oceania
# ...

# %%
df.loc[df['genre_1'] == 'Shapeshifters', 'genre_1'] = 'Fantasy'

# %%
df.loc[df['year_publication'] == 'Biography']
# Out:
# Empty DataFrame
# Columns: [author_id, author_name, author_page_url, birthplace, book_average_rating, book_fullurl, book_id, book_title, genre_1, genre_2, pages, year_publication, fiction_nonfiction]
# Index: []

# %%
df.iloc[6745,8] = 'Young Adult'

# %%
df.drop(631, inplace=True)

# %%
df.reset_index(drop=True)
# Out:
#      author_id           author_name  \
# 0        74489    Victoria Thompson
# 1      5618190  Mimi Jean Pamfiloff
# 2        36122    Patricia C. Wrede
# 3      4833990         Jillian Dodd
# 4         7956           Mary Roach
# ...        ...                   ...
# 7691  12020546          S.D. Wasley
# 7692   8386732         Victoria Zak
# 7693    108007       Dakota Cassidy
# 7694   6543639      Krystal Shannan
# 7695   5246010          Bryce Evans
#
#                                author_page_url      birthplace  \
# 0         /author/show/74489.Victoria_Thompson  USA and Canada
# 1     /author/show/5618190.Mimi_Jean_Pamfiloff  USA and Canada
# 2          /author/show/36122.Patricia_C_Wrede  USA and Canada
# 3            /author/show/4833990.Jillian_Dodd         Unknown
# 4                 /author/show/7956.Mary_Roach  USA and Canada
# ...                                        ...             ...
# 7691          /author/show/12020546.S_D_Wasley         Oceania
# ...

# %%
df.loc[df['genre_1'] == 'Music']
# Out:
#      author_id         author_name                        author_page_url  \
# 1083   8195738        L.B. Dunbar         /author/show/8195738.L_B_Dunbar
# 1445   7164331        Skye Turner        /author/show/7164331.Skye_Turner
# 1450   7114580   Renee Lee Fisher   /author/show/7114580.Renee_Lee_Fisher
# 2393  16304661         Lee  Piper         /author/show/16304661.Lee_Piper
# 3012   7202946  Claudia Y. Burgoa   /author/show/7202946.Claudia_Y_Burgoa
# 3356   7114580   Renee Lee Fisher   /author/show/7114580.Renee_Lee_Fisher
# 3681   5835506    Michelle Mankin    /author/show/5835506.Michelle_Mankin
# 4561   1036517       Taylor Swift       /author/show/1036517.Taylor_Swift
# 5618    990148        Miley Cyrus         /author/show/990148.Miley_Cyrus
# 6965   7248355         N.J. Frost          /author/show/7248355.N_J_Frost
# 7301   6885618   Sharisse Coulter   /author/show/6885618.Sharisse_Coulter
#
#           birthplace book_average_rating  \
# ...

# %%
df.iloc[5618]
# Out:
# author_id                                                           5030
# author_name                                                    Amy Sohn
# author_page_url                               /author/show/5030.Amy_Sohn
# birthplace                                                USA and Canada
# book_average_rating                                                 4.25
# book_fullurl           https://www.goodreads.com/book/show/10232099-s...
# book_id                                                         10232099
# book_title                                             Sex and the City
# genre_1                                                       Nonfiction
# genre_2                                                 See top shelves…
# pages                                                                176
# year_publication                                                    2002
# fiction_nonfiction                                            Nonfiction
# ...

# %%
df.to_csv('dataset5', index=False)

# %%
df = pd.read_csv('dataset5')
df
# Out:
#      author_id           author_name  \
# 0        74489    Victoria Thompson
# 1      5618190  Mimi Jean Pamfiloff
# 2        36122    Patricia C. Wrede
# 3      4833990         Jillian Dodd
# 4         7956           Mary Roach
# ...        ...                   ...
# 7691  12020546          S.D. Wasley
# 7692   8386732         Victoria Zak
# 7693    108007       Dakota Cassidy
# 7694   6543639      Krystal Shannan
# 7695   5246010          Bryce Evans
#
#                                author_page_url      birthplace  \
# 0         /author/show/74489.Victoria_Thompson  USA and Canada
# 1     /author/show/5618190.Mimi_Jean_Pamfiloff  USA and Canada
# 2          /author/show/36122.Patricia_C_Wrede  USA and Canada
# 3            /author/show/4833990.Jillian_Dodd         Unknown
# 4                 /author/show/7956.Mary_Roach  USA and Canada
# ...                                        ...             ...
# 7691          /author/show/12020546.S_D_Wasley         Oceania
# ...

# %%
df.loc[df['genre_1'] == 'Psychology']
# Out:
#      author_id             author_name  \
# 2817      1506  Elisabeth Kübler-Ross
# 4169   7872519           D.K. Cassidy
# 4322      3335          Alice  Miller
# 4423    217172         Carol S. Dweck
# 6016   4678212           Bon Blossman
# 7438   5374565   Annabelle R. Charbit
# 7493    202733      Marsha M. Linehan
#
#                                author_page_url      birthplace  \
# 2817   /author/show/1506.Elisabeth_K_bler_Ross          Europe
# 4169          /author/show/7872519.D_K_Cassidy         Unknown
# 4322            /author/show/3335.Alice_Miller          Europe
# 4423         /author/show/217172.Carol_S_Dweck  USA and Canada
# 6016         /author/show/4678212.Bon_Blossman  USA and Canada
# 7438  /author/show/5374565.Annabelle_R_Charbit          Europe
# 7493      /author/show/202733.Marsha_M_Linehan  USA and Canada
#
#      book_average_rating                                       book_fullurl  \
# ...

# %%
df.loc[df['author_name'] == 'Janae Keyes ', 'genre_1'] = 'Romance'

# %%
df.iloc[3284]
# Out:
# author_id                                                        4175328
# author_name                                        Glennon Doyle Melton
# author_page_url                /author/show/4175328.Glennon_Doyle_Melton
# birthplace                                                       Unknown
# book_average_rating                                                 4.08
# book_fullurl           https://www.goodreads.com/book/show/31845516-l...
# book_id                                                         31845516
# book_title                                                 Love Warrior
# genre_1                                                    Autobiography
# genre_2                                                       Nonfiction
# pages                                                                272
# year_publication                                                    2016
# fiction_nonfiction                                         Autobiography
# ...

# %%
df.drop(3279, inplace=True)

# %%
df.drop(5617, inplace=True)

# %%
df.iloc[4560]
# Out:
# author_id                                                          15590
# author_name                                               Mary  Stewart
# author_page_url                          /author/show/15590.Mary_Stewart
# birthplace                                                        Europe
# book_average_rating                                                 4.38
# book_fullurl           https://www.goodreads.com/book/show/27689.Mary...
# book_id                                                            27689
# book_title                                Mary Stewart's Merlin Trilogy
# genre_1                                                          Fantasy
# genre_2                                                          Fiction
# pages                                                                928
# year_publication                                                    1978
# fiction_nonfiction                                               Fantasy
# ...

# %%
df.drop(4560, inplace=True)

# %%
df.iloc[3012,10] = '320'

# %%
df.iloc[3012,9] = 'Romance'

# %%
df.iloc[3012,3] = 'Latin America'

# %%
def fiction_nonfiction(i):
    if i in ['Mystery', 'Romance', 'Fantasy', 'Young Adult', 'Paranormal', 'Historical', 'Science Fiction', 'Fiction','Classics', 'New Adult', 'Contemporary', 'Womens Fiction', 'Horror', 'Humor', 'Sequential Art', 'Lgbt', 'Sports and Games', 'War', 'Dark', 'Childrens','Christian Fiction', 'Womens Fiction', 'Adult Fiction','Short Stories', 'Animals', 'Music', 'Poetry', 'Novels', 'Thriller', 'Anthologies', 'Magical Realism', 'Realistic Fiction', 'Suspense','Category Romance', 'Science Fiction Fantasy', 'Literary Fiction','Novella', 'Asian Literature', 'Biblical Fiction', 'Adventure', 'Literature', 'Westerns', 'Dark Fantasy','Comics', 'Drama', 'Manga', 'Erotica']:
        return 'Fiction'
    elif i in ['Nonfiction', 'Autobiography', 'Biography', 'Self Help', 'Politics','Economics', 'Social Science', 'Writing', 'Mental Health', 'Art', 'Travel', 'History', 'Feminism']:
        return 'Nonfiction'
    else:
        return i

# %%
df['fiction_nonfiction'] = list(map(fiction_nonfiction, df['fiction_nonfiction']))

# %%
df
# Out:
#      author_id           author_name  \
# 0        74489    Victoria Thompson
# 1      5618190  Mimi Jean Pamfiloff
# 2        36122    Patricia C. Wrede
# 3      4833990         Jillian Dodd
# 4         7956           Mary Roach
# ...        ...                   ...
# 7691  12020546          S.D. Wasley
# 7692   8386732         Victoria Zak
# 7693    108007       Dakota Cassidy
# 7694   6543639      Krystal Shannan
# 7695   5246010          Bryce Evans
#
#                                author_page_url      birthplace  \
# 0         /author/show/74489.Victoria_Thompson  USA and Canada
# 1     /author/show/5618190.Mimi_Jean_Pamfiloff  USA and Canada
# 2          /author/show/36122.Patricia_C_Wrede  USA and Canada
# 3            /author/show/4833990.Jillian_Dodd         Unknown
# 4                 /author/show/7956.Mary_Roach  USA and Canada
# ...                                        ...             ...
# 7691          /author/show/12020546.S_D_Wasley         Oceania
# ...

# %%
df.to_csv('dataset6', index=False)

# %%
df['fiction_nonfiction'].unique()
# Out:
# array(['Fiction', 'Nonfiction', 'Warfare', 'Crime', 'Language',
#        'Mythology', 'World War II', 'Death', 'Christian', 'Cultural',
#        'Amish', 'Holiday', 'Psychology', 'Philosophy', 'Glbt',
#        'Sexuality', 'Parenting', 'Gardening', 'Spirituality', 'Sociology',
#        'Business', 'Food and Drink', 'Media Tie In', 'Health', 'Religion',
#        'Couture', 'Polyamorous', 'Retellings', 'Inspirational',
#        'Unfinished', 'Sports'], dtype=object)

# %%
df.loc[df['fiction_nonfiction'] == 'Business']
# Out:
#      author_id        author_name                        author_page_url  \
# 3784   1150547  Stephanie Palmer   /author/show/1150547.Stephanie_Palmer
# 6514   4602925       Lorii Myers        /author/show/4602925.Lorii_Myers
# 7327   4848577     Karyn Gerrard      /author/show/4848577.Karyn_Gerrard
#
#           birthplace book_average_rating  \
# 3784         Unknown                3.79
# 6514  USA and Canada                4.08
# 7327  USA and Canada                4.08
#
#                                            book_fullurl   book_id  \
# 3784  https://www.goodreads.com/book/show/2607485-go...   2607485
# 6514  https://www.goodreads.com/book/show/12964250-t...  12964250
# 7327  https://www.goodreads.com/book/show/22913902-s...  22913902
#
#                                              book_title   genre_1  \
# 3784         Good in a Room: How to Sell Yourself (a...  Business
# 6514         Targeting Success, Develop the Right Bu...  Business
# ...

# %%
df.iloc[643,8] = 'Young Adult'

# %%
df.iloc[7268,8] = 'Historical Fiction'

# %%
df.iloc[5308,8] = 'Contemporary'
df.iloc[5308,12] = "Fiction"

# %%
df.iloc[6876,8] = 'Fantasy'
df.iloc[6876,12] = 'Fiction'

# %%
df.iloc[7559,3] = 'Europe'

# %%
df.iloc[7344,9] = 'Adult Ficiton'

# %%
df.iloc[1328,12] = 'Fiction'

# %%
df.to_csv('dataset7.csv', index=False)

# %%
df = pd.read_csv('dataset7.csv')
df
# Out:
#      author_id           author_name  \
# 0        74489    Victoria Thompson
# 1      5618190  Mimi Jean Pamfiloff
# 2        36122    Patricia C. Wrede
# 3      4833990         Jillian Dodd
# 4         7956           Mary Roach
# ...        ...                   ...
# 7688  12020546          S.D. Wasley
# 7689   8386732         Victoria Zak
# 7690    108007       Dakota Cassidy
# 7691   6543639      Krystal Shannan
# 7692   5246010          Bryce Evans
#
#                                author_page_url      birthplace  \
# 0         /author/show/74489.Victoria_Thompson  USA and Canada
# 1     /author/show/5618190.Mimi_Jean_Pamfiloff  USA and Canada
# 2          /author/show/36122.Patricia_C_Wrede  USA and Canada
# 3            /author/show/4833990.Jillian_Dodd         Unknown
# 4                 /author/show/7956.Mary_Roach  USA and Canada
# ...                                        ...             ...
# 7688          /author/show/12020546.S_D_Wasley         Oceania
# ...

# %%
df.loc[df['fiction_nonfiction'] == 'Business', 'fiction_nonfiction'] = 'Nonfiction'

# %%
df.drop(7322, inplace=True)

# %%
df['fiction_nonfiction'].unique()
# Out:
# array(['Fiction', 'Nonfiction', 'Warfare', 'Crime', 'Language',
#        'Mythology', 'World War II', 'Death', 'Christian', 'Cultural',
#        'Amish', 'Holiday', 'Psychology', 'Philosophy', 'Glbt',
#        'Sexuality', 'Parenting', 'Gardening', 'Spirituality', 'Sociology',
#        'Food and Drink', 'Media Tie In', 'Health', 'Religion', 'Couture',
#        'Polyamorous', 'Inspirational', 'Unfinished', 'Sports'],
#       dtype=object)

# %%
df.loc[df['fiction_nonfiction'] == 'Mythology', 'fiction_nonfiction'] = 'Fiction'

# %%
df.loc[df['fiction_nonfiction'] == 'World War II', 'fiction_nonfiction'] = 'Nonfiction'

# %%
df.loc[df['fiction_nonfiction'] == 'Death']
# Out:
#      author_id     author_name                   author_page_url birthplace  \
# 1536   8054196  Lance   Rubin   /author/show/8054196.Lance_Rubin    Unknown
#
#      book_average_rating                                       book_fullurl  \
# 1536                3.84  https://www.goodreads.com/book/show/24721702-d...
#
#        book_id                         book_title genre_1      genre_2 pages  \
# 1536  24721702         Denton Little's Deathdate    Death  Young Adult   346
#
#      year_publication fiction_nonfiction
# 1536             2015              Death

# %%
df.drop(1537, inplace = True)

# %%
df.reset_index(drop=True)
# Out:
#      author_id           author_name  \
# 0        74489    Victoria Thompson
# 1      5618190  Mimi Jean Pamfiloff
# 2        36122    Patricia C. Wrede
# 3      4833990         Jillian Dodd
# 4         7956           Mary Roach
# ...        ...                   ...
# 7686  12020546          S.D. Wasley
# 7687   8386732         Victoria Zak
# 7688    108007       Dakota Cassidy
# 7689   6543639      Krystal Shannan
# 7690   5246010          Bryce Evans
#
#                                author_page_url      birthplace  \
# 0         /author/show/74489.Victoria_Thompson  USA and Canada
# 1     /author/show/5618190.Mimi_Jean_Pamfiloff  USA and Canada
# 2          /author/show/36122.Patricia_C_Wrede  USA and Canada
# 3            /author/show/4833990.Jillian_Dodd         Unknown
# 4                 /author/show/7956.Mary_Roach  USA and Canada
# ...                                        ...             ...
# 7686          /author/show/12020546.S_D_Wasley         Oceania
# ...

# %%
df.to_csv('dataset8.csv', index=False)

# %%
df = pd.read_csv('dataset8.csv')
df
# Out:
#      author_id           author_name  \
# 0        74489    Victoria Thompson
# 1      5618190  Mimi Jean Pamfiloff
# 2        36122    Patricia C. Wrede
# 3      4833990         Jillian Dodd
# 4         7956           Mary Roach
# ...        ...                   ...
# 7686  12020546          S.D. Wasley
# 7687   8386732         Victoria Zak
# 7688    108007       Dakota Cassidy
# 7689   6543639      Krystal Shannan
# 7690   5246010          Bryce Evans
#
#                                author_page_url      birthplace  \
# 0         /author/show/74489.Victoria_Thompson  USA and Canada
# 1     /author/show/5618190.Mimi_Jean_Pamfiloff  USA and Canada
# 2          /author/show/36122.Patricia_C_Wrede  USA and Canada
# 3            /author/show/4833990.Jillian_Dodd         Unknown
# 4                 /author/show/7956.Mary_Roach  USA and Canada
# ...                                        ...             ...
# 7686          /author/show/12020546.S_D_Wasley         Oceania
# ...

# %%
df.drop(1806, inplace= True)

# %%
df['fiction_nonfiction'].unique()
# Out:
# array(['Fiction', 'Nonfiction', 'Warfare', 'Crime', 'Language', 'Death',
#        'Christian', 'Cultural', 'Amish', 'Holiday', 'Psychology',
#        'Philosophy', 'Glbt', 'Sexuality', 'Parenting', 'Gardening',
#        'Spirituality', 'Sociology', 'Food and Drink', 'Media Tie In',
#        'Health', 'Religion', 'Couture', 'Polyamorous', 'Inspirational',
#        'Unfinished', 'Sports'], dtype=object)

# %%
df.loc[df['fiction_nonfiction'] == 'Philosophy', 'fiction_nonfiction'] = 'Nonfiction'

# %%
df.iloc[7344,7] ='Dear Shameless Death'
df.iloc[7344,8] = 'Novel'
df.iloc[7344,9] = 'Magical Realism'
df.iloc[7344,12] = 'Fiction'
df.iloc[7344,5] = 'https://www.goodreads.com/book/show/322732.Dear_Shameless_Death?from_search=true&from_srp=true&qid=0mpWwXBX1w&rank='

# %%
df.iloc[2067,12] = 'Nonfiction'
df.iloc[2067,8] = 'Biography'

# %%
df.loc[df['fiction_nonfiction'] == 'Sexuality', 'fiction_nonfiction'] = 'Nonfiction'

# %%
df.loc[df['fiction_nonfiction'] == 'Spirituality', 'fiction_nonfiction'] = 'Nonfiction'

# %%
df.iloc[5169,8] = 'Poetry'
df.iloc[5169,12] = 'Fiction'

# %%
df.iloc[6054,8] = 'Self Help'
df.iloc[6054,12] = 'Nonfiction'

# %%
df.iloc[7673,9] = 'Self Help'
df.iloc[7673, 12] = 'Nonfiction'

# %%
df.loc[df['fiction_nonfiction'] == 'Food and Drink', 'fiction_nonfiction'] = 'Nonfiction'

# %%
df.loc[df['fiction_nonfiction'] == 'Media Tie In', 'fiction_nonfiction'] = 'Fiction'

# %%
df.loc[df['genre_1'] == 'Media Tie In', 'genre_1'] = 'Science Fiction'

# %%
df.loc[df['fiction_nonfiction'] == 'Polyamorous', 'fiction_nonfiction'] = 'Fiction'

# %%
df.loc[df['fiction_nonfiction'] == 'Inspirational', 'fiction_nonfiction'] = 'Nonfiction'
df.loc[df['genre_1'] == 'Inspirational', 'genre_1'] = 'Self Help'

# %%
df.loc[df['fiction_nonfiction'] == 'Christian']
# Out:
#      author_id         author_name                         author_page_url  \
# 1805     36065  Richard J. Foster      /author/show/36065.Richard_J_Foster
# 1808     13288     Hannah Hurnard        /author/show/13288.Hannah_Hurnard
# 3283  15683552       Lisa Hawkins       /author/show/15683552.Lisa_Hawkins
# 3306      8352        Joyce Meyer            /author/show/8352.Joyce_Meyer
# 4460     41954   Robin Jones Gunn      /author/show/41954.Robin_Jones_Gunn
# 4678    140274        Sally Laity          /author/show/140274.Sally_Laity
# 4743    118456   Janice  Thompson      /author/show/118456.Janice_Thompson
# 4920    470018        Cindy Bauer          /author/show/470018.Cindy_Bauer
# 6054     10418         Beth Moore            /author/show/10418.Beth_Moore
# 6752     17560   Elizabeth George      /author/show/17560.Elizabeth_George
# 7673   6951311  Phylline Phillips   /author/show/6951311.Phylline_Phillips
#
#           birthplace book_average_rating  \
# ...

# %%
df['genre_1'].unique()
# Out:
# array(['Mystery', 'Romance', 'Fantasy', 'Young Adult', 'Nonfiction',
#        'Paranormal', 'Historical', 'Science Fiction', 'Fiction',
#        'Classics', 'New Adult', 'Contemporary', 'Womens Fiction',
#        'Horror', 'Autobiography', 'Humor', 'Sequential Art', 'Lgbt',
#        'Sports and Games', 'War', 'Dark', 'Childrens',
#        'Christian Fiction', 'Warfare', 'Biography', 'Adult Fiction',
#        'Short Stories', 'Animals', 'Self Help', 'Politics',
#        'Mental Health', 'Erotica', 'Crime', 'Travel', 'History',
#        'Language', 'Poetry', 'Novels', 'Feminism', 'Thriller', 'Music',
#        'Mythology', 'World War II', 'Anthologies', 'Death',
#        'Magical Realism', 'Christian', 'Realistic Fiction', 'Suspense',
#        'Category Romance', 'Cultural', 'Science Fiction Fantasy', 'Amish',
#        'Holiday', 'Psychology', 'Philosophy', 'Glbt', 'Sexuality',
#        'Parenting', 'Gardening', 'Spirituality', 'Literary Fiction',
# ...

# %%
df.iloc[4919,9] = 'Christian Fiction'
df.iloc[4919,12] = 'Fiction'

# %%
df.iloc[6751, 9] = 'Nonfiction'
df.iloc[6751, 12] = 'Nonfiction'

# %%
def cleaning_christian(df, col1, col2, col_change):
    fiction_conditions = (df[col1] == 'Christian') & (df[col2].isin(['Fiction', 'Christian Fiction', 'Romance']))
    df.loc[fiction_conditions, col_change] = 'Fiction'

    nonfiction_conditions = (df[col1] == 'Christian') & (df[col2].isin(['Religion', 'Nonfiction', 'Inspirational', 'Spirituality']))
    df.loc[nonfiction_conditions, col_change] = 'Nonfiction'

# %%
cleaning_christian(df, 'genre_1', 'genre_2', 'fiction_nonfiction')
df
# Out:
#      author_id           author_name  \
# 0        74489    Victoria Thompson
# 1      5618190  Mimi Jean Pamfiloff
# 2        36122    Patricia C. Wrede
# 3      4833990         Jillian Dodd
# 4         7956           Mary Roach
# ...        ...                   ...
# 7686  12020546          S.D. Wasley
# 7687   8386732         Victoria Zak
# 7688    108007       Dakota Cassidy
# 7689   6543639      Krystal Shannan
# 7690   5246010          Bryce Evans
#
#                                author_page_url      birthplace  \
# 0         /author/show/74489.Victoria_Thompson  USA and Canada
# 1     /author/show/5618190.Mimi_Jean_Pamfiloff  USA and Canada
# 2          /author/show/36122.Patricia_C_Wrede  USA and Canada
# 3            /author/show/4833990.Jillian_Dodd         Unknown
# 4                 /author/show/7956.Mary_Roach  USA and Canada
# ...                                        ...             ...
# 7686          /author/show/12020546.S_D_Wasley         Oceania
# ...

# %%
df.loc[df['genre_1'] == 'Amish', 'genre_1'] = 'Fiction'

# %%
df.loc[df['genre_1'] == 'Holiday', 'genre_1'] = 'Fiction'

# %%
df.loc[df['genre_1'] == 'Psychology', 'genre_1'] = 'Nonfiction'

# %%
df.iloc[6011,7] = 'Shillingstone Witch'
df.iloc[6011,8] = 'Young Adult'
df.iloc[6011, 9] = 'Mystery'
df.iloc[6011, 12] = 'Fiction'

# %%
df.iloc[6011]
# Out:
# author_id                                                        4678212
# author_name                                                Bon Blossman
# author_page_url                        /author/show/4678212.Bon_Blossman
# birthplace                                                USA and Canada
# book_average_rating                                                 4.47
# book_fullurl           https://www.goodreads.com/book/show/26571498-s...
# book_id                                                         26571498
# book_title                                           Shillingstone Witch
# genre_1                                                      Young Adult
# genre_2                                                          Mystery
# pages                                                                348
# year_publication                                                    2015
# fiction_nonfiction                                               Fiction
# ...

# %%
df.iloc[7430,7] = 'A Life Lived Ridiculously'
df.iloc[7430, 8] = 'Fiction'
df.iloc[7430, 9] = 'Psychology'
df.iloc[7430, 12] = 'Fiction'

# %%
df.iloc[7430]
# Out:
# author_id                                                        7075461
# author_name                                               Ashelyn Drake
# author_page_url                       /author/show/7075461.Ashelyn_Drake
# birthplace                                                USA and Canada
# book_average_rating                                                 3.67
# book_fullurl           https://www.goodreads.com/book/show/17452685-i...
# book_id                                                         17452685
# book_title                                     A Life Lived Ridiculously
# genre_1                                                          Fiction
# genre_2                                                       Psychology
# pages                                                                257
# year_publication                                                    2014
# fiction_nonfiction                                               Fiction
# ...

# %%
df.iloc[4166]
# Out:
# author_id                                                        7872519
# author_name                                                D.K. Cassidy
# author_page_url                         /author/show/7872519.D_K_Cassidy
# birthplace                                                       Unknown
# book_average_rating                                                 4.17
# book_fullurl           https://www.goodreads.com/book/show/25125709-c...
# book_id                                                         25125709
# book_title                    Curious Reality: From the World of "Spi...
# genre_1                                                       Nonfiction
# genre_2                                                          Fantasy
# pages                                                                164
# year_publication                                                    2015
# fiction_nonfiction                                            Psychology
# ...

# %%
df.iloc[4166, 8] = 'Fantasy'
df.iloc[4166, 9] = 'Short Stories'
df.iloc[4166, 12] = 'Fiction'

# %%
df = df.drop(df[df['year_publication'] == 'Writing'].index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7690 entries, 0 to 7690
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   author_id            7690 non-null   object
#  1   author_name          7690 non-null   object
#  2   author_page_url      7690 non-null   object
#  3   birthplace           7690 non-null   object
#  4   book_average_rating  7690 non-null   object
#  5   book_fullurl         7690 non-null   object
#  6   book_id              7690 non-null   object
#  7   book_title           7690 non-null   object
#  8   genre_1              7690 non-null   object
#  9   genre_2              7690 non-null   object
#  10  pages                7690 non-null   object
#  11  year_publication     7598 non-null   object
#  12  fiction_nonfiction   7690 non-null   object
# dtypes: object(13)
# memory usage: 841.1+ KB

# %%
df['fiction_nonfiction'].unique()
# Out:
# array(['Fiction', 'Nonfiction', 'Warfare', 'Crime', 'Language', 'Death',
#        'Cultural', 'Amish', 'Holiday', 'Psychology', 'Glbt', 'Parenting',
#        'Gardening', 'Sociology', 'Health', 'Religion', 'Couture',
#        'Unfinished', 'Sports'], dtype=object)

# %%
df.to_csv('dataset_with_fiction-nonfiction.csv', index= False)
